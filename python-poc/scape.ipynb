# %% [markdown]
# Clean implementation of Scrape

# %%
import trends
# Out:
# Device set to use mps:0

# %%
import espn

# %%
trends_data = trends.get_trends()

# %%
trends_data
# Out:
#                                Trend                Search Volume  \
# 0                       pope francis  100K+\narrow_upward\n1,000%
# 1               beterbiev vs bivol 2    100K+\narrow_upward\n400%
# 2                           canadien   50K+\narrow_upward\n1,000%
# 3             upmc memorial shooting     50K+\narrow_upward\n700%
# 4                lynne marie stewart     20K+\narrow_upward\n700%
# 5                     steve smith sr   20K+\narrow_upward\n1,000%
# 6             aston villa vs chelsea  100K+\narrow_upward\n1,000%
# 7                           cq brown    100K+\narrow_upward\n400%
# 8   valencia c. f. - atlético madrid   20K+\narrow_upward\n1,000%
# 9                   shakur stevenson     20K+\narrow_upward\n600%
# 10            german elections polls     20K+\narrow_upward\n600%
# 11              capitals vs penguins     20K+\narrow_upward\n500%
# 12                    torino - milan     20K+\narrow_upward\n900%
# ...

# %%
# Example usage: Search for a topic and extract articles
search_query = trends_data['Trend'][1]
df_espn_articles = espn.search_espn_and_extract_articles(search_query)
article_url = df_espn_articles['URL'][0]
# Example usage:
article_text = espn.extract_espn_article_text(article_url)
# Display the article text
print(article_text)
# Out:
# Saturday's show in Riyadh, Saudi Arabia has been hailed the best card boxing has ever seen -- and for good reason. Boxing promoters are known for their hyperbole and selling events they stage. But the seven fights set to take place at the Kingdom Arena are all good enough to have been the main event at sold-out arenas. The biggest of the lot is the main event, the undisputed light heavyweight title rematch between Artur Beterbiev and Dmitry Bivol, two of the best pound-for-pound boxers in the world. But much more is happening earlier in the same ring in what might be the biggest night of boxing in 2025. Four world titles and three interim titles will all be on the line. What are the best fights, why should you watch them, and who is expected to win? ESPN ranks the fights for you. Artur Beterbiev comes away with a majority decision victory over Dmitry Bivol in front of a packed crowd in Saudi Arabia. Not many boxers have managed to stay on top of the game into their 40s. Bernard Hopki
# ...
