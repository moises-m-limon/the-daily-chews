# %% [markdown]
# Clean implementation of Scrape

# %%
import trends
# Out:
# Device set to use mps:0

# %%
trends_data = trends.get_trends()

# %%
trends_data
# Out:
#                                Trend                Search Volume  \
# 0   valencia c. f. - atlético madrid   50K+\narrow_upward\n1,000%
# 1                    kash patel wife  100K+\narrow_upward\n1,000%
# 2                       pope francis   50K+\narrow_upward\n1,000%
# 3                           canadien   50K+\narrow_upward\n1,000%
# 4               beterbiev vs bivol 2     50K+\narrow_upward\n300%
# 5             aston villa vs chelsea  100K+\narrow_upward\n1,000%
# 6                               upmc     50K+\narrow_upward\n800%
# 7                    torino vs milan   20K+\narrow_upward\n1,000%
# 8                           cq brown    100K+\narrow_upward\n600%
# 9                lynne marie stewart     20K+\narrow_upward\n800%
# 10               arsenal vs west ham   50K+\narrow_upward\n1,000%
# 11                         red wings     20K+\narrow_upward\n800%
# 12                 warriors vs kings  100K+\narrow_upward\n1,000%
# ...
